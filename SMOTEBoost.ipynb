# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

x = df[['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']]
y = df['Class']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.20, random_state=0)
print('xtrain shape')
print(xtrain.shape)
print('xtest shape')
print(xtest.shape)
# Out:
# xtrain shape
# (227845, 30)
# xtest shape
# (56962, 30)

# %%
'''Extreme Gradient Boost Algorithm on reduced dimensions data'''

from xgboost.sklearn import XGBClassifier

# Create the XGB classifier, xgb_model.
xgb_model = XGBClassifier()

# List the default parameters.
print(xgb_model.get_xgb_params())
# Out:
# {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'binary:logistic', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1, 'verbosity': 1}

# %%
xgb_model.fit(xtrain, ytrain, eval_metric=['error'], eval_set=[((xtrain, ytrain)),(xtest, ytest)])
# Out:
# [0]	validation_0-error:0.000641	validation_1-error:0.000772
# [1]	validation_0-error:0.000654	validation_1-error:0.000772
# [2]	validation_0-error:0.000645	validation_1-error:0.000772
# [3]	validation_0-error:0.000628	validation_1-error:0.00072
# [4]	validation_0-error:0.000628	validation_1-error:0.00072
# [5]	validation_0-error:0.000628	validation_1-error:0.00072
# [6]	validation_0-error:0.000597	validation_1-error:0.00072
# [7]	validation_0-error:0.000619	validation_1-error:0.000702
# [8]	validation_0-error:0.000623	validation_1-error:0.000702
# [9]	validation_0-error:0.000614	validation_1-error:0.000702
# [10]	validation_0-error:0.000557	validation_1-error:0.00072
# [11]	validation_0-error:0.000535	validation_1-error:0.000737
# [12]	validation_0-error:0.000557	validation_1-error:0.000737
# [13]	validation_0-error:0.000553	validation_1-error:0.000737
# [14]	validation_0-error:0.000553	validation_1-error:0.000737
# [15]	validation_0-error:0.00054	validation_1-error:0.00072
# [16]	validation_0-error:0.00047	validation_1-error:0.000685
# [17]	validation_0-error:0.000461	validation_1-error:0.000667
# [18]	validation_0-error:0.000435	validation_1-error:0.000614
# [19]	validation_0-error:0.000426	validation_1-error:0.000632
# [20]	validation_0-error:0.000452	validation_1-error:0.000614
# [21]	validation_0-error:0.000443	validation_1-error:0.000597
# [22]	validation_0-error:0.000443	validation_1-error:0.000614
# [23]	validation_0-error:0.000421	validation_1-error:0.000597
# [24]	validation_0-error:0.000417	validation_1-error:0.000579
# [25]	validation_0-error:0.000417	validation_1-error:0.000597
# [26]	validation_0-error:0.000417	validation_1-error:0.000614
# [27]	validation_0-error:0.000421	validation_1-error:0.000632
# [28]	validation_0-error:0.000421	validation_1-error:0.000632
# [29]	validation_0-error:0.000421	validation_1-error:0.000614
# [30]	validation_0-error:0.000421	validation_1-error:0.000614
# [31]	validation_0-error:0.000382	validation_1-error:0.000632
# [32]	validation_0-error:0.000386	validation_1-error:0.000597
# [33]	validation_0-error:0.000382	validation_1-error:0.000579
# [34]	validation_0-error:0.000382	validation_1-error:0.000597
# [35]	validation_0-error:0.000382	validation_1-error:0.000597
# [36]	validation_0-error:0.000391	validation_1-error:0.000579
# [37]	validation_0-error:0.000386	validation_1-error:0.000562
# [38]	validation_0-error:0.000395	validation_1-error:0.000579
# [39]	validation_0-error:0.000386	validation_1-error:0.000579
# [40]	validation_0-error:0.000377	validation_1-error:0.000579
# [41]	validation_0-error:0.000386	validation_1-error:0.000562
# [42]	validation_0-error:0.000386	validation_1-error:0.000562
# [43]	validation_0-error:0.000382	validation_1-error:0.000579
# [44]	validation_0-error:0.000377	validation_1-error:0.000562
# [45]	validation_0-error:0.000369	validation_1-error:0.000562
# [46]	validation_0-error:0.000369	validation_1-error:0.000562
# [47]	validation_0-error:0.000369	validation_1-error:0.000562
# [48]	validation_0-error:0.000373	validation_1-error:0.000562
# [49]	validation_0-error:0.000364	validation_1-error:0.000562
# [50]	validation_0-error:0.000364	validation_1-error:0.000562
# [51]	validation_0-error:0.000364	validation_1-error:0.000544
# [52]	validation_0-error:0.000364	validation_1-error:0.000544
# [53]	validation_0-error:0.00036	validation_1-error:0.000544
# [54]	validation_0-error:0.00036	validation_1-error:0.000544
# [55]	validation_0-error:0.00036	validation_1-error:0.000562
# [56]	validation_0-error:0.00036	validation_1-error:0.000544
# [57]	validation_0-error:0.000369	validation_1-error:0.000544
# [58]	validation_0-error:0.000369	validation_1-error:0.000544
# [59]	validation_0-error:0.000369	validation_1-error:0.000544
# [60]	validation_0-error:0.00036	validation_1-error:0.000544
# [61]	validation_0-error:0.00036	validation_1-error:0.000544
# [62]	validation_0-error:0.00036	validation_1-error:0.000544
# [63]	validation_0-error:0.000364	validation_1-error:0.000544
# [64]	validation_0-error:0.000369	validation_1-error:0.000544
# [65]	validation_0-error:0.000364	validation_1-error:0.000544
# [66]	validation_0-error:0.000364	validation_1-error:0.000544
# [67]	validation_0-error:0.000356	validation_1-error:0.000544
# [68]	validation_0-error:0.000356	validation_1-error:0.000544
# [69]	validation_0-error:0.000356	validation_1-error:0.000544
# [70]	validation_0-error:0.000351	validation_1-error:0.000544
# [71]	validation_0-error:0.000351	validation_1-error:0.000544
# [72]	validation_0-error:0.000351	validation_1-error:0.000544
# [73]	validation_0-error:0.000351	validation_1-error:0.000544
# [74]	validation_0-error:0.000351	validation_1-error:0.000544
# [75]	validation_0-error:0.00036	validation_1-error:0.000544
# [76]	validation_0-error:0.000351	validation_1-error:0.000544
# [77]	validation_0-error:0.000351	validation_1-error:0.000527
# [78]	validation_0-error:0.000347	validation_1-error:0.000527
# [79]	validation_0-error:0.000347	validation_1-error:0.000527
# [80]	validation_0-error:0.000347	validation_1-error:0.000527
# [81]	validation_0-error:0.000347	validation_1-error:0.000527
# [82]	validation_0-error:0.000347	validation_1-error:0.000527
# [83]	validation_0-error:0.000347	validation_1-error:0.000527
# [84]	validation_0-error:0.000347	validation_1-error:0.000544
# [85]	validation_0-error:0.000347	validation_1-error:0.000544
# [86]	validation_0-error:0.000347	validation_1-error:0.000544
# [87]	validation_0-error:0.000347	validation_1-error:0.000544
# [88]	validation_0-error:0.000347	validation_1-error:0.000544
# [89]	validation_0-error:0.000342	validation_1-error:0.000544
# [90]	validation_0-error:0.000342	validation_1-error:0.000527
# [91]	validation_0-error:0.000342	validation_1-error:0.000544
# [92]	validation_0-error:0.000342	validation_1-error:0.000544
# [93]	validation_0-error:0.000342	validation_1-error:0.000544
# [94]	validation_0-error:0.000342	validation_1-error:0.000544
# [95]	validation_0-error:0.000342	validation_1-error:0.000544
# [96]	validation_0-error:0.000342	validation_1-error:0.000527
# [97]	validation_0-error:0.000342	validation_1-error:0.000527
# [98]	validation_0-error:0.000338	validation_1-error:0.000544
# [99]	validation_0-error:0.000338	validation_1-error:0.000544
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

y_pred = xgb_model.predict(xtest)  #predicts
print('confusion matrix')
print(metrics.confusion_matrix(ytest, y_pred))
print('classification report')
print(metrics.classification_report(ytest, y_pred))
print("-----------------------------------------------------------------------------------------")
print("Accuracy is :")
print(metrics.accuracy_score(ytest, y_pred))
print('Area under the curve : %f' % (metrics.roc_auc_score(ytest, y_pred)))
# Out:
# confusion matrix
# [[56851    10]
#  [   21    80]]
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.89      0.79      0.84       101
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.90      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# -----------------------------------------------------------------------------------------
# Accuracy is :
# 0.9994557775359011
# Area under the curve : 0.895952

# %%
# !pip3 install imblearn
# Out:
# Collecting imblearn
#   Using cached https://files.pythonhosted.org/packages/81/a7/4179e6ebfd654bd0eac0b9c06125b8b4c96a9d0a8ff9e9507eb2a26d2d7e/imblearn-0.0-py2.py3-none-any.whl
# Collecting imbalanced-learn (from imblearn)
#   Using cached https://files.pythonhosted.org/packages/e6/62/08c14224a7e242df2cef7b312d2ef821c3931ec9b015ff93bb52ec8a10a3/imbalanced_learn-0.5.0-py3-none-any.whl
# Collecting scipy>=0.17 (from imbalanced-learn->imblearn)
#   Using cached https://files.pythonhosted.org/packages/29/50/a552a5aff252ae915f522e44642bb49a7b7b31677f9580cfd11bcc869976/scipy-1.3.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting scikit-learn>=0.21 (from imbalanced-learn->imblearn)
#   Using cached https://files.pythonhosted.org/packages/a0/c5/d2238762d780dde84a20b8c761f563fe882b88c5a5fb03c056547c442a19/scikit_learn-0.21.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy>=1.11 (from imbalanced-learn->imblearn)
#   Using cached https://files.pythonhosted.org/packages/75/92/57179ed45307ec6179e344231c47da7f3f3da9e2eee5c8ab506bd279ce4e/numpy-1.17.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting joblib>=0.11 (from imbalanced-learn->imblearn)
#   Using cached https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl
# Installing collected packages: numpy, scipy, joblib, scikit-learn, imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.5.0 imblearn-0.0 joblib-0.13.2 numpy-1.17.1 scikit-learn-0.21.3 scipy-1.3.1

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE 

x = df[['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']]
y = df['Class']

'''Increase the fraud samples from 102 to 500'''

sm = SMOTE(random_state=42,ratio={1:1000})
X_res, y_res = sm.fit_sample(x, y)
print('Resampled dataset shape {}'.format(Counter(y_res)))
# Out:
# Resampled dataset shape Counter({0: 284315, 1: 1000})

# %%
'''Split the resampled data into train & test data with 80:20 mix'''
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X_res, y_res, test_size=0.20, random_state=0)
print('xtrain shape')
print(xtrain.shape)
print('xtest shape')
print(xtest.shape)
# Out:
# xtrain shape
# (228252, 30)
# xtest shape
# (57063, 30)

# %%
from xgboost.sklearn import XGBClassifier

# Create the XGB classifier, xgb_model.
xgb_model = XGBClassifier()

# List the default parameters.
print(xgb_model.get_xgb_params())
# Out:
# {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'binary:logistic', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 0, 'subsample': 1, 'verbosity': 1}

# %%
xgb_model.fit(xtrain, ytrain, eval_metric=['error'], eval_set=[((xtrain, ytrain)),(xtest, ytest)])
# Out:
# [0]	validation_0-error:0.001008	validation_1-error:0.001034
# [1]	validation_0-error:0.001003	validation_1-error:0.001034
# [2]	validation_0-error:0.001008	validation_1-error:0.001034
# [3]	validation_0-error:0.001003	validation_1-error:0.001034
# [4]	validation_0-error:0.001003	validation_1-error:0.001034
# [5]	validation_0-error:0.001003	validation_1-error:0.001034
# [6]	validation_0-error:0.000867	validation_1-error:0.000894
# [7]	validation_0-error:0.000872	validation_1-error:0.000894
# [8]	validation_0-error:0.000867	validation_1-error:0.000894
# [9]	validation_0-error:0.000867	validation_1-error:0.000894
# [10]	validation_0-error:0.000867	validation_1-error:0.000894
# [11]	validation_0-error:0.000863	validation_1-error:0.000876
# [12]	validation_0-error:0.000859	validation_1-error:0.000876
# [13]	validation_0-error:0.00085	validation_1-error:0.000876
# [14]	validation_0-error:0.000824	validation_1-error:0.000876
# [15]	validation_0-error:0.000828	validation_1-error:0.000876
# [16]	validation_0-error:0.000802	validation_1-error:0.000876
# [17]	validation_0-error:0.000806	validation_1-error:0.000876
# [18]	validation_0-error:0.000797	validation_1-error:0.000876
# [19]	validation_0-error:0.000775	validation_1-error:0.000876
# [20]	validation_0-error:0.000767	validation_1-error:0.000876
# [21]	validation_0-error:0.000762	validation_1-error:0.000876
# [22]	validation_0-error:0.000767	validation_1-error:0.000841
# [23]	validation_0-error:0.000745	validation_1-error:0.000841
# [24]	validation_0-error:0.00074	validation_1-error:0.000841
# [25]	validation_0-error:0.000723	validation_1-error:0.000841
# [26]	validation_0-error:0.00071	validation_1-error:0.000841
# [27]	validation_0-error:0.00071	validation_1-error:0.000824
# [28]	validation_0-error:0.000697	validation_1-error:0.000841
# [29]	validation_0-error:0.000692	validation_1-error:0.000841
# [30]	validation_0-error:0.000688	validation_1-error:0.000841
# [31]	validation_0-error:0.000692	validation_1-error:0.000841
# [32]	validation_0-error:0.000688	validation_1-error:0.000841
# [33]	validation_0-error:0.000688	validation_1-error:0.000824
# [34]	validation_0-error:0.000679	validation_1-error:0.000789
# [35]	validation_0-error:0.000675	validation_1-error:0.000789
# [36]	validation_0-error:0.00067	validation_1-error:0.000789
# [37]	validation_0-error:0.00067	validation_1-error:0.000806
# [38]	validation_0-error:0.000666	validation_1-error:0.000806
# [39]	validation_0-error:0.000657	validation_1-error:0.000806
# [40]	validation_0-error:0.000662	validation_1-error:0.000789
# [41]	validation_0-error:0.000657	validation_1-error:0.000789
# [42]	validation_0-error:0.000662	validation_1-error:0.000789
# [43]	validation_0-error:0.000653	validation_1-error:0.000789
# [44]	validation_0-error:0.000657	validation_1-error:0.000771
# [45]	validation_0-error:0.000657	validation_1-error:0.000771
# [46]	validation_0-error:0.000648	validation_1-error:0.000771
# [47]	validation_0-error:0.000648	validation_1-error:0.000789
# [48]	validation_0-error:0.000653	validation_1-error:0.000771
# [49]	validation_0-error:0.000648	validation_1-error:0.000771
# [50]	validation_0-error:0.00064	validation_1-error:0.000771
# [51]	validation_0-error:0.000644	validation_1-error:0.000771
# [52]	validation_0-error:0.000635	validation_1-error:0.000771
# [53]	validation_0-error:0.000644	validation_1-error:0.000789
# [54]	validation_0-error:0.000644	validation_1-error:0.000789
# [55]	validation_0-error:0.00064	validation_1-error:0.000789
# [56]	validation_0-error:0.000648	validation_1-error:0.000806
# [57]	validation_0-error:0.000648	validation_1-error:0.000824
# [58]	validation_0-error:0.000648	validation_1-error:0.000806
# [59]	validation_0-error:0.000648	validation_1-error:0.000806
# [60]	validation_0-error:0.000653	validation_1-error:0.000806
# [61]	validation_0-error:0.000653	validation_1-error:0.000806
# [62]	validation_0-error:0.000648	validation_1-error:0.000806
# [63]	validation_0-error:0.00064	validation_1-error:0.000806
# [64]	validation_0-error:0.00064	validation_1-error:0.000806
# [65]	validation_0-error:0.00064	validation_1-error:0.000824
# [66]	validation_0-error:0.00064	validation_1-error:0.000824
# [67]	validation_0-error:0.000565	validation_1-error:0.000771
# [68]	validation_0-error:0.000565	validation_1-error:0.000771
# [69]	validation_0-error:0.00064	validation_1-error:0.000824
# [70]	validation_0-error:0.000635	validation_1-error:0.000806
# [71]	validation_0-error:0.000556	validation_1-error:0.000736
# [72]	validation_0-error:0.000561	validation_1-error:0.000736
# [73]	validation_0-error:0.000556	validation_1-error:0.000736
# [74]	validation_0-error:0.000561	validation_1-error:0.000736
# [75]	validation_0-error:0.000565	validation_1-error:0.000736
# [76]	validation_0-error:0.000561	validation_1-error:0.000736
# [77]	validation_0-error:0.000561	validation_1-error:0.000736
# [78]	validation_0-error:0.000561	validation_1-error:0.000736
# [79]	validation_0-error:0.000561	validation_1-error:0.000736
# [80]	validation_0-error:0.000539	validation_1-error:0.000719
# [81]	validation_0-error:0.000561	validation_1-error:0.000736
# [82]	validation_0-error:0.000561	validation_1-error:0.000736
# [83]	validation_0-error:0.000552	validation_1-error:0.000719
# [84]	validation_0-error:0.000556	validation_1-error:0.000736
# [85]	validation_0-error:0.000556	validation_1-error:0.000719
# [86]	validation_0-error:0.000539	validation_1-error:0.000719
# [87]	validation_0-error:0.00053	validation_1-error:0.000701
# [88]	validation_0-error:0.000534	validation_1-error:0.000701
# [89]	validation_0-error:0.000534	validation_1-error:0.000701
# [90]	validation_0-error:0.00053	validation_1-error:0.000719
# [91]	validation_0-error:0.00053	validation_1-error:0.000719
# [92]	validation_0-error:0.000534	validation_1-error:0.000719
# [93]	validation_0-error:0.000534	validation_1-error:0.000719
# [94]	validation_0-error:0.00053	validation_1-error:0.000736
# [95]	validation_0-error:0.00053	validation_1-error:0.000701
# [96]	validation_0-error:0.000526	validation_1-error:0.000701
# [97]	validation_0-error:0.000526	validation_1-error:0.000683
# [98]	validation_0-error:0.000521	validation_1-error:0.000666
# [99]	validation_0-error:0.000526	validation_1-error:0.000683
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

y_pred = xgb_model.predict(xtest)  #predicts
print('confusion matrix')
print(metrics.confusion_matrix(ytest, y_pred))
print('classification report')
print(metrics.classification_report(ytest, y_pred))
print("-----------------------------------------------------------------------------------------")
print("Accuracy is :")
print(metrics.accuracy_score(ytest, y_pred))
print('Area under the curve : %f' % (metrics.roc_auc_score(ytest, y_pred)))
# Out:
# confusion matrix
# [[56842    11]
#  [   28   182]]
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56853
#            1       0.94      0.87      0.90       210
#
#     accuracy                           1.00     57063
#    macro avg       0.97      0.93      0.95     57063
# weighted avg       1.00      1.00      1.00     57063
#
# -----------------------------------------------------------------------------------------
# Accuracy is :
# 0.9993165448714578
# Area under the curve : 0.933237
